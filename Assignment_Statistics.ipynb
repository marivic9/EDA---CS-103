# %% [markdown]
# <a href="https://colab.research.google.com/github/marivic9/EDA-CS-103/blob/main/Assignment_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
#packages

from pandas import read_csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Four different types of measurement scales described in statistics: nominal, ordinal, interval, and ratio.
#
# *Nominal*: a type of data that is used to label variables without providing any quantitative value.
#
# *Ordinal*: a type of data that categorizes and orders variables according to their relative ranking or position.
#
# *Interval*: a type of data that measures variables along a scale with equal intervals between successive data points.
#
# *Ratio*: a type of data that has a true zero point and allows for the comparison of absolute quantities.

# %% [markdown]
# # **Datasets** - Top Companies by Price-to-Earnings ratio, students_adaptability_level_online_education, and monthly_temperature_aomori_city.

# %%
filename = 'Top Companies by Price-to-Earnings ratio.csv'
companies = pd.read_csv('/gdrive/MyDrive/Colab Notebooks/statistics/Top Companies by Price-to-Earnings ratio.csv')
companies.head()
# Out:
#    Rank              Company  Stock Symbol  price-to-earnings ratio(TTM)  \
# 0     1               Kuuhubb        KUU.V                      0.142857
# 1     2             Mesoblast         MESO                      0.197598
# 2     3           Spin Master       TOY.TO                      0.212578
# 3     4  Performance Shipping         PSHG                      0.254268
# 4     5            Netcapital         NCPL                      0.259362
#
#    price (USD) Company Origin
# 0       0.0100         Canada
# 1       7.9550      Australia
# 2      22.0486         Canada
# 3       2.1500         Greece
# 4       0.1219  United States

# %%
filename = 'students_adaptability_level_online_education.csv'
students = pd.read_csv('/gdrive/MyDrive/Colab Notebooks/statistics/students_adaptability_level_online_education.csv')
students.head()
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0
#
#   Self Lms  Device Adaptivity Level
# 0       No     Tab         Moderate
# ...

# %%
filename = 'monthly_temperature_aomori_city.csv'
temp = pd.read_csv('/gdrive/MyDrive/Colab Notebooks/statistics/monthly_temperature_aomori_city.csv')
temp.head()
# Out:
#    year  month  temperature
# 0  1882      1         -0.4
# 1  1882      2         -0.6
# 2  1882      3          1.2
# 3  1882      4          8.9
# 4  1882      5         12.1

# %%
#Descriptive Analysis

companies.describe()
companies.describe(include='all')
# Out:
#                Rank   Company  Stock Symbol  price-to-earnings ratio(TTM)  \
# count   8395.000000       8395         8394                  8.395000e+03
# unique          NaN       8391         8394                           NaN
# top             NaN  Castellum        KUU.V                           NaN
# freq            NaN          2            1                           NaN
# mean    4198.000000        NaN          NaN                 -3.136391e+14
# std     2423.572088        NaN          NaN                  4.805840e+16
# min        1.000000        NaN          NaN                 -4.100000e+18
# 25%     2099.500000        NaN          NaN                 -6.385985e-01
# 50%     4198.000000        NaN          NaN                  9.115080e+00
# 75%     6296.500000        NaN          NaN                  2.393225e+01
# max     8395.000000        NaN          NaN                  1.600000e+18
#
#          price (USD) Company Origin
# count    8395.000000           8393
# ...

# %%
students.describe()
students.describe(include='all')
# Out:
#        Gender    Age Education Level Institution Type IT Student Location  \
# count    1205   1205            1205             1205       1205     1205
# unique      2      6               3                2          2        2
# top       Boy  21-25          School   Non Government         No      Yes
# freq      663    374             530              823        901      935
#
#        Load-shedding Financial Condition Internet Type Network Type  \
# count           1205                1205          1205         1205
# unique             2                   3             2            3
# top              Low                 Mid   Mobile Data           4G
# freq            1004                 878           695          775
#
#        Class Duration Self Lms  Device Adaptivity Level
# count            1205     1205    1205             1205
# unique              3        2       3                3
# top               1-3       No  Mobile         Moderate
# ...

# %%
temp.describe()
temp.describe(include='all')
# Out:
#               year        month  temperature
# count  1668.000000  1668.000000  1668.000000
# mean   1951.000000     6.500000     9.646283
# std      40.136839     3.453088     8.724708
# min    1882.000000     1.000000    -5.700000
# 25%    1916.000000     3.750000     1.100000
# 50%    1951.000000     6.500000     9.950000
# 75%    1986.000000     9.250000    17.600000
# max    2020.000000    12.000000    26.000000

# %% [markdown]
# # NOMINAL

# %%
import matplotlib.pyplot as plt

# Assuming 'students' is the DataFrame and 'Gender' is the column
gender_counts = students['Gender'].value_counts()

plt.figure(figsize=(8, 8))  # Set the figure size (optional)
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'pink'])
plt.title('Distribution of Students by Gender')
plt.show()

# %% [markdown]
# The pie chart depicting the gender distribution of students reveals a male-dominated population, with males representing 55% and females 45%, highlighting a significant gender gap. This imbalance raises important questions about educational equity and may influence program design to foster inclusivity while addressing biases that affect career choices in various fields. Further analysis incorporating factors such as age groups, academic programs, and socioeconomic backgrounds could provide deeper insights into the reasons behind this disparity and identify opportunities for improvement.

# %% [markdown]
# # ORDINAL

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x='month', y='temperature', data=temp, color='skyblue')

plt.xlabel("Month")
plt.ylabel("Temperature")
plt.title("Temperature Distribution Across Months")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The temperature trend graph reveals a distinct seasonal pattern characterized by warmer temperatures from June to August and cooler conditions at the year's start and end. This variation suggests significant fluctuations between different years or locations, likely influenced by factors such as weather anomalies, climate variability, and local geography. Further analysis—incorporating statistical evaluations, historical comparisons, and geographic assessments—could enhance our understanding of these trends and elucidate underlying influences on regional climatic patterns.

# %% [markdown]
# # INTERVAL

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x='month', y='temperature', data=temp, color='skyblue')

plt.xlabel("Month")
plt.ylabel("Temperature")
plt.title("Temperature Distribution Across Months")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The analysis of the box plot illustrating temperature distribution across months reveals a distinct seasonal trend, with elevated temperatures observed from June to August and lower readings at the year's beginning and end. Variability in monthly temperatures is indicated by the size of boxes and whiskers, highlighting significant fluctuations during certain periods while also revealing outliers that may signify extreme weather events. Further statistical evaluation, historical comparisons, and geographic assessments are recommended to deepen our understanding of these trends and their underlying causes within this tropical climate context.

# %% [markdown]
# # RATIO

# %%
print(companies.describe())

plt.figure(figsize=(15, 6))
sns.histplot(companies['price-to-earnings ratio(TTM)'], bins=30, kde=False, color = 'skyblue')
plt.ylabel('Counts of Companies')
plt.xlabel('P/E Ratio')
plt.title('Distribution of P/E Ratios')
plt.show()

pe_counts = companies['price-to-earnings ratio(TTM)'].value_counts().sort_index()
print(pe_counts)
# Out:
#               Rank  price-to-earnings ratio(TTM)   price (USD)
# count  8395.000000                  8.395000e+03   8395.000000
# mean   4198.000000                 -3.136391e+14     69.600708
# std    2423.572088                  4.805840e+16    388.730535
# min       1.000000                 -4.100000e+18      0.000000
# 25%    2099.500000                 -6.385985e-01      2.935000
# 50%    4198.000000                  9.115080e+00     12.630000
# 75%    6296.500000                  2.393225e+01     40.297650
# max    8395.000000                  1.600000e+18  12100.000000
# price-to-earnings ratio(TTM)
# -4.100000e+18    1
# -1.330000e+17    1
# -1.040410e+06    1
# -3.215650e+05    1
# -1.709260e+04    1
#                 ..
#  9.935120e+04    1
#  1.137860e+05    1
#  3.347040e+05    1
#  3.730340e+05    1
#  1.600000e+18    1
# Name: count, Length: 7755, dtype: int64

# %% [markdown]
# The histogram analysis of P/E ratios reveals a right-skewed distribution characterized by a significant number of companies with low or near-zero earnings, alongside outliers reflecting extremely high valuations. This suggests that while the market perceives certain firms to be strong growth candidates, many others may either be struggling financially or are overvalued relative to their earnings potential. Further investigation into descriptive statistics and industry benchmarks could provide valuable insights into underlying trends and investment opportunities within this dataset.
